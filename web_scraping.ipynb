# %% [markdown]
# <a href="https://colab.research.google.com/github/jyoti0225/Multimodal-models/blob/main/web_scraping.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## Visual Question Answering

# %%
# test.py
import torch
from PIL import Image
from transformers import AutoModel, AutoTokenizer

# %%
model = AutoModel.from_pretrained('openbmb/MiniCPM-Llama3-V-2_5-int4', trust_remote_code=True)
tokenizer = AutoTokenizer.from_pretrained('openbmb/MiniCPM-Llama3-V-2_5-int4', trust_remote_code=True)
model.eval()

image = Image.open('jetblue.png').convert('RGB')
question = 'What is in the image?'
msgs = [{'role': 'user', 'content': question}]

res = model.chat(
    image=image,
    msgs=msgs,
    tokenizer=tokenizer,
    sampling=True, # if sampling=False, beam_search will be used by default
    temperature=0.7,
    # system_prompt='' # pass system_prompt if needed
)
print(res)
# Out:
# Unused kwargs: ['_load_in_4bit', '_load_in_8bit', 'quant_method']. These kwargs are not used in <class 'transformers.utils.quantization_config.BitsAndBytesConfig'>.
# `low_cpu_mem_usage` was None, now set to True since model is quantized.
# model.safetensors.index.json:   0%|          | 0.00/244k [00:00<?, ?B/s]
# ...
# model-00001-of-00002.safetensors:   0%|          | 0.00/4.65G [00:00<?, ?B/s]
# model-00002-of-00002.safetensors:   0%|          | 0.00/1.51G [00:00<?, ?B/s]
# Loading checkpoint shards:   0%|          | 0/2 [00:00<?, ?it/s]
# generation_config.json:   0%|          | 0.00/121 [00:00<?, ?B/s]
# tokenizer_config.json:   0%|          | 0.00/50.9k [00:00<?, ?B/s]
# tokenizer.json:   0%|          | 0.00/9.08M [00:00<?, ?B/s]
# special_tokens_map.json:   0%|          | 0.00/459 [00:00<?, ?B/s]
# Special tokens have been added in the vocabulary, make sure the associated word embeddings are fine-tuned or trained.
# ...

# %%
image = Image.open('jetblue.png').convert('RGB')
question = 'Extract all the Jetblue travels offers'
msgs = [{'role': 'user', 'content': question}]

res = model.chat(
    image=image,
    msgs=msgs,
    tokenizer=tokenizer,
    sampling=True, # if sampling=False, beam_search will be used by default
    temperature=0.7,
    # system_prompt='' # pass system_prompt if needed
)
print(res)
# Out:
# JetBlue is offering several deals on its website. One of the promotions is a 30% discount on Solo bags for Memorial Day, which seems to be an exclusive offer. Additionally, there are mentions of 'Today's fly deals' and various locations such as West Palm Beach, West Palm Beach again (which might be a different deal or location), Orlando, and another Orlando deal. Each of these locations has a corresponding dollar amount next to them, suggesting the price or value of the deal. The exact details of each deal are not specified in the provided information, but they seem to be part of JetBlue's travel offerings.

# %%
image = Image.open('jetblue.png').convert('RGB')
question = 'Extract all the Jetblue travels offers from different banners and provide in list'
msgs = [{'role': 'user', 'content': question}]

res = model.chat(
    image=image,
    msgs=msgs,
    tokenizer=tokenizer,
    sampling=True, # if sampling=False, beam_search will be used by default
    temperature=0.7,
    # system_prompt='' # pass system_prompt if needed
)
print(res)
# Out:
# The JetBlue travel offers extracted from the banners are as follows:
#
# 1. JetBlue Plus Card: This offer is highlighted in a banner that suggests benefits or an incentive related to the JetBlue Plus Card, although the specific details of the offer are not provided in the text.
#
# 2. Trip protection to the rescue: This appears to be another promotional offer, possibly related to travel insurance or assistance services provided by JetBlue, aimed at protecting customers' trips.
#
# 3. Swimming in options: This banner likely refers to a variety of travel options available through JetBlue, suggesting flexibility and choice for travelers.
#
# 4. 30% off Solo bags this Memorial Day: This offer seems to be a discount on Solo bags, which could be related to travel gear, with a promotion valid for Memorial Day.
#
# These offers seem to be part of a broader marketing strategy to attract and retain customers by providing them with various incentives and benefits associated with travel.

# %%
image = Image.open('jetblue.png').convert('RGB')
question = 'Extract all the barclays card offers'
msgs = [{'role': 'user', 'content': question}]

res = model.chat(
    image=image,
    msgs=msgs,
    tokenizer=tokenizer,
    sampling=True, # if sampling=False, beam_search will be used by default
    temperature=0.7,
    # system_prompt='' # pass system_prompt if needed
)
print(res)
# Out:
# The Barclays card offers extracted from the webpage are:
#
# 1. "60,000 Bonus Miles & $100 Statement Credit" - This offer is associated with the Barclays Arrival Plus World Mastercard.
# 2. "50,000 Bonus Miles & $100 Statement Credit" - This offer is also linked to the Barclays Arrival Plus World Mastercard.
# 3. "40,000 Bonus Miles & $100 Statement Credit" - This offer is again related to the Barclays Arrival Plus World Mastercard.
#
# Each of these offers mentions a specific number of bonus miles and a statement credit as part of the deal for the card.

# %%
# test.py
import torch
from PIL import Image
from transformers import AutoModel, AutoTokenizer

model = AutoModel.from_pretrained('openbmb/MiniCPM-V-2', trust_remote_code=True, torch_dtype=torch.bfloat16)
# For Nvidia GPUs support BF16 (like A100, H100, RTX3090)
model = model.to(device='cuda', dtype=torch.bfloat16)
# For Nvidia GPUs do NOT support BF16 (like V100, T4, RTX2080)
#model = model.to(device='cuda', dtype=torch.float16)
# For Mac with MPS (Apple silicon or AMD GPUs).
# Run with `PYTORCH_ENABLE_MPS_FALLBACK=1 python test.py`
#model = model.to(device='mps', dtype=torch.float16)

tokenizer = AutoTokenizer.from_pretrained('openbmb/MiniCPM-V-2', trust_remote_code=True)
model.eval()

image = Image.open('jetblue.png').convert('RGB')
question = 'What is in the image?'
msgs = [{'role': 'user', 'content': question}]

res, context, _ = model.chat(
    image=image,
    msgs=msgs,
    context=None,
    tokenizer=tokenizer,
    sampling=True,
    temperature=0.7
)
print(res)
# Out:
# ...
# model-00001-of-00002.safetensors:  98%|#########8| 4.90G/4.99G [00:00<?, ?B/s]
# model-00002-of-00002.safetensors:   0%|          | 0.00/1.88G [00:00<?, ?B/s]
# Loading checkpoint shards:   0%|          | 0/2 [00:00<?, ?it/s]
# generation_config.json:   0%|          | 0.00/111 [00:00<?, ?B/s]
# tokenizer_config.json:   0%|          | 0.00/3.34k [00:00<?, ?B/s]
# tokenizer.model:   0%|          | 0.00/1.99M [00:00<?, ?B/s]
# special_tokens_map.json:   0%|          | 0.00/651 [00:00<?, ?B/s]
# tokenizer.json:   0%|          | 0.00/6.20M [00:00<?, ?B/s]
# ...

# %%
image = Image.open('jetblue.png').convert('RGB')
question = 'Extract all the barclays card offer from the image'
msgs = [{'role': 'user', 'content': question}]

res, context, _ = model.chat(
    image=image,
    msgs=msgs,
    context=None,
    tokenizer=tokenizer,
    sampling=True,
    temperature=0.7
)
print(res)
# Out:
# The Barclays card offer in the image states: "30% off Solo bags this Memorial Day."

# %%
image = Image.open('jetblue.png').convert('RGB')
question = 'Extract all the barclays card offers if present, else say no info'
msgs = [{'role': 'user', 'content': question}]

res, context, _ = model.chat(
    image=image,
    msgs=msgs,
    context=None,
    tokenizer=tokenizer,
    sampling=True,
    temperature=0.7
)
print(res)
# Out:
# No Barclays card offers are present in the provided information.

# %%
image = Image.open('jetblue.png').convert('RGB')
question = 'Extract all the Jetblue travels offers from different banners and provide in points. For each banner, mention the its location and size'
msgs = [{'role': 'user', 'content': question}]

res, context, _ = model.chat(
    image=image,
    msgs=msgs,
    context=None,
    tokenizer=tokenizer,
    sampling=True,
    temperature=0.7
)
print(res)
# Out:
# Based on the information provided, here are some of JetBlue's travel offers with their respective locations and sizes:
# 1. "Jet better with JETBLUE Plus Card"<box> 389 402 605 472</box>

# %%
image = Image.open('jetblue.png').convert('RGB')
question = 'Extract all the Jetblue travels offers from different banners and provide in list'#. For each banner, mention the its location and size'
msgs = [{'role': 'user', 'content': question}]

res, context, _ = model.chat(
    image=image,
    msgs=msgs,
    context=None,
    tokenizer=tokenizer,
    sampling=True,
    temperature=0.7
)
print(res)
# Out:
# Here are the Jetblue travel offers mentioned in different banners:
# 1. "Jet better with the new Jetsuit Card"<box> 367 409 582 447</box>— This offer is likely related to a card or loyalty program for frequent travelers, offering benefits such as additional perks and discounts on flights within their network of airlines operated by JetBlue Airways Corporation (JBLU). The mention suggests that this deal could be part of an ongoing promotion from jetblueairlinescorporation(jblu), which operates under various airline codes including JFK at John F Kennedy International Airport located near New York City's borough Manhattan area where it has its main hub operation based out of Terminal B/C gates C-D & E gate A... These details indicate potential savings opportunities available through using these cards when booking trips via airfare tickets sold directly online only — all deals come without any middleman fees so you can save more money while traveling!

# %%
import requests
from PIL import Image
from transformers import BlipProcessor, BlipForQuestionAnswering

processor = BlipProcessor.from_pretrained("Salesforce/blip-vqa-base")
model = BlipForQuestionAnswering.from_pretrained("Salesforce/blip-vqa-base")

img_url = 'jetblue.png'
raw_image = Image.open(img_url).convert('RGB')

question = "Extract all the Jetblue travels offers from different banners"
inputs = processor(raw_image, question, return_tensors="pt")

out = model.generate(**inputs,max_new_tokens=200)
print(processor.decode(out[0], skip_special_tokens=True))
# Out:
# wwwsappellarcom

# %%
import torch
from transformers import AutoTokenizer, AutoModelForCausalLM
ckpt_path = "internlm/internlm-xcomposer2-vl-7b"
tokenizer = AutoTokenizer.from_pretrained(ckpt_path, trust_remote_code=True).cuda()
# Set `torch_dtype=torch.float16` to load model in float16, otherwise it will be loaded as float32 and might cause OOM Error.
model = AutoModelForCausalLM.from_pretrained(ckpt_path, torch_dtype=torch.float16, trust_remote_code=True).cuda()
model = model.eval()
# Out:
# tokenizer_config.json:   0%|          | 0.00/401 [00:00<?, ?B/s]
# tokenization_internlm_xcomposer2.py:   0%|          | 0.00/9.18k [00:00<?, ?B/s]
# A new version of the following files was downloaded from https://huggingface.co/internlm/internlm-xcomposer2-vl-7b:
# - tokenization_internlm_xcomposer2.py
# . Make sure to double-check they do not contain any added malicious code. To avoid downloading new versions of the code file, you can pin a revision.
# tokenizer.model:   0%|          | 0.00/1.48M [00:00<?, ?B/s]
# special_tokens_map.json:   0%|          | 0.00/95.0 [00:00<?, ?B/s]
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-27-676f979eb5ab> in <cell line: 4>()
#       2 from transformers import AutoTokenizer, AutoModelForCausalLM
#       3 ckpt_path = "internlm/internlm-xcomposer2-vl-7b"
# ...

# %%
import torch
from PIL import Image
from transformers import AutoModelForCausalLM, AutoTokenizer
from transformers import BitsAndBytesConfig


bnb_cfg = BitsAndBytesConfig(
    load_in_4bit=True,
    bnb_4bit_compute_dtype=torch.float16,
    llm_int8_skip_modules=["mm_projector", "vision_model"],
)

model_id = "qresearch/llama-3-vision-alpha-hf"
model = AutoModelForCausalLM.from_pretrained(
    model_id,
    trust_remote_code=True,
    torch_dtype=torch.float16,
    quantization_config=bnb_cfg,
)

tokenizer = AutoTokenizer.from_pretrained(
    model_id,
    use_fast=True,
)

image = Image.open("jetblue.png")

print(
    tokenizer.decode(
        model.answer_question(image, "question", tokenizer),
        skip_special_tokens=True,
    )
)
# Out:
# config.json:   0%|          | 0.00/1.02k [00:00<?, ?B/s]
# configuration_llamavision.py:   0%|          | 0.00/376 [00:00<?, ?B/s]
# A new version of the following files was downloaded from https://huggingface.co/qresearch/llama-3-vision-alpha-hf:
# - configuration_llamavision.py
# . Make sure to double-check they do not contain any added malicious code. To avoid downloading new versions of the code file, you can pin a revision.
# modeling_llamavision.py:   0%|          | 0.00/4.90k [00:00<?, ?B/s]
# A new version of the following files was downloaded from https://huggingface.co/qresearch/llama-3-vision-alpha-hf:
# - modeling_llamavision.py
# . Make sure to double-check they do not contain any added malicious code. To avoid downloading new versions of the code file, you can pin a revision.
# `low_cpu_mem_usage` was None, now set to True since model is quantized.
# model.safetensors.index.json:   0%|          | 0.00/74.9k [00:00<?, ?B/s]
# ...

# %%
from transformers import ViltProcessor, ViltForQuestionAnswering
import requests
from PIL import Image

# prepare image + question
img = "jetblue.png"
image = Image.open(img).convert('RGB')
text = "Extract all the Jetblue travels offers from different banners and list in points"

processor = ViltProcessor.from_pretrained("dandelin/vilt-b32-finetuned-vqa")
model = ViltForQuestionAnswering.from_pretrained("dandelin/vilt-b32-finetuned-vqa")

# prepare inputs
encoding = processor(image, text, return_tensors="pt")

# forward pass
outputs = model(**encoding)
logits = outputs.logits
idx = logits.argmax(-1).item()
print("Predicted answer:", model.config.id2label[idx])
# Out:
# Predicted answer: yes

# %%
from transformers import AutoProcessor, AutoModelForCausalLM
from huggingface_hub import hf_hub_download
from PIL import Image

processor = AutoProcessor.from_pretrained("microsoft/git-base-textvqa")
model = AutoModelForCausalLM.from_pretrained("microsoft/git-base-textvqa")

# file_path = hf_hub_download(repo_id="nielsr/textvqa-sample", filename="bus.png", repo_type="dataset")
image = Image.open('jetblue.png').convert("RGB")

pixel_values = processor(images=image, return_tensors="pt").pixel_values

question = "Extract all the Jetblue travels offers from different banners"

input_ids = processor(text=question, add_special_tokens=False).input_ids
input_ids = [processor.tokenizer.cls_token_id] + input_ids
input_ids = torch.tensor(input_ids).unsqueeze(0)

generated_ids = model.generate(pixel_values=pixel_values, input_ids=input_ids, max_length=50)
print(processor.batch_decode(generated_ids, skip_special_tokens=True))
# Out:
# ['extract all the jetblue travels offers from different banners']

# %%
import requests
from PIL import Image
from transformers import BlipProcessor, Blip2ForConditionalGeneration

model_name = "ethzanalytics/blip2-flan-t5-xl-sharded"
processor = BlipProcessor.from_pretrained(model_name)
model = Blip2ForConditionalGeneration.from_pretrained(model_name)

# img_url = 'https://storage.googleapis.com/sfr-vision-language-research/BLIP/demo.jpg'
raw_image = Image.open('jetblue.png').convert('RGB')

question ="Extract all the Jetblue travels offers from different banners"
inputs = processor(raw_image, question, return_tensors="pt")

out = model.generate(**inputs)
print(processor.decode(out[0], skip_special_tokens=True))
# Out:
# preprocessor_config.json:   0%|          | 0.00/431 [00:00<?, ?B/s]
# tokenizer_config.json:   0%|          | 0.00/2.69k [00:00<?, ?B/s]
# tokenizer.json:   0%|          | 0.00/2.42M [00:00<?, ?B/s]
# added_tokens.json:   0%|          | 0.00/58.0 [00:00<?, ?B/s]
# special_tokens_map.json:   0%|          | 0.00/2.27k [00:00<?, ?B/s]
# config.json:   0%|          | 0.00/7.77k [00:00<?, ?B/s]
# model.safetensors.index.json:   0%|          | 0.00/133k [00:00<?, ?B/s]
# ...
# model-00001-of-00009.safetensors:   0%|          | 0.00/1.99G [00:00<?, ?B/s]
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-35-7dbff779d890> in <cell line: 7>()
#       5 model_name = "ethzanalytics/blip2-flan-t5-xl-sharded"
#       6 processor = BlipProcessor.from_pretrained(model_name)
# ----> 7 model = Blip2ForConditionalGeneration.from_pretrained(model_name)
#       8
# ...

# %%
import requests
from PIL import Image
from transformers import Pix2StructForConditionalGeneration, Pix2StructProcessor

# image_url = "https://huggingface.co/datasets/huggingface/documentation-images/resolve/main/transformers/tasks/ai2d-demo.jpg"
image = Image.open('jetblue.png').convert('RGB')

model = Pix2StructForConditionalGeneration.from_pretrained("google/pix2struct-ai2d-base")
processor = Pix2StructProcessor.from_pretrained("google/pix2struct-ai2d-base")

question ="Extract all the Jetblue travels offers from different banners"

inputs = processor(images=image, text=question, return_tensors="pt")

predictions = model.generate(**inputs)
print(processor.decode(predictions[0], skip_special_tokens=True))
# Out:
# config.json:   0%|          | 0.00/4.89k [00:00<?, ?B/s]
# model.safetensors:   0%|          | 0.00/565M [00:00<?, ?B/s]
# preprocessor_config.json:   0%|          | 0.00/249 [00:00<?, ?B/s]
# tokenizer_config.json:   0%|          | 0.00/2.58k [00:00<?, ?B/s]
# spiece.model:   0%|          | 0.00/851k [00:00<?, ?B/s]
# tokenizer.json:   0%|          | 0.00/3.27M [00:00<?, ?B/s]
# special_tokens_map.json:   0%|          | 0.00/2.20k [00:00<?, ?B/s]
# Arial.TTF:   0%|          | 0.00/276k [00:00<?, ?B/s]
# Jetblue travels offers from different banners>

# %%
from transformers import AutoModelForCausalLM, AutoTokenizer
import torch
from PIL import Image

checkpoint = "qihoo360/360VL-8B"

model = AutoModelForCausalLM.from_pretrained(checkpoint, torch_dtype=torch.float16, device_map='auto', trust_remote_code=True).eval()
tokenizer = AutoTokenizer.from_pretrained(checkpoint, trust_remote_code=True)
vision_tower = model.get_vision_tower()
vision_tower.load_model()
vision_tower.to(device="cuda", dtype=torch.float16)
image_processor = vision_tower.image_processor
tokenizer.pad_token = tokenizer.eos_token


image = Image.open("jetblue.png").convert('RGB')
query ="Extract all the Jetblue travels offers from different banners"

terminators = [
    tokenizer.convert_tokens_to_ids("<|eot_id|>",)
]

inputs = model.build_conversation_input_ids(tokenizer, query=query, image=image, image_processor=image_processor)

input_ids = inputs["input_ids"].to(device='cuda', non_blocking=True)
images = inputs["image"].to(dtype=torch.float16, device='cuda', non_blocking=True)

output_ids = model.generate(
    input_ids,
    images=images,
    do_sample=False,
    eos_token_id=terminators,
    num_beams=1,
    max_new_tokens=512,
    use_cache=True)

input_token_len = input_ids.shape[1]
outputs = tokenizer.batch_decode(output_ids[:, input_token_len:], skip_special_tokens=True)[0]
outputs = outputs.strip()
print(outputs)
# Out:
# config.json:   0%|          | 0.00/3.57k [00:00<?, ?B/s]
# modeling_360vl.py:   0%|          | 0.00/31.4k [00:00<?, ?B/s]
# A new version of the following files was downloaded from https://huggingface.co/qihoo360/360VL-8B:
# - modeling_360vl.py
# . Make sure to double-check they do not contain any added malicious code. To avoid downloading new versions of the code file, you can pin a revision.
# model.safetensors.index.json:   0%|          | 0.00/87.7k [00:00<?, ?B/s]
# ...
# model-00001-of-00004.safetensors:   0%|          | 0.00/4.98G [00:00<?, ?B/s]
# model-00002-of-00004.safetensors:   0%|          | 0.00/5.00G [00:00<?, ?B/s]
# model-00003-of-00004.safetensors:   0%|          | 0.00/4.92G [00:00<?, ?B/s]
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-38-9aeec34816c3> in <cell line: 7>()
#       5 checkpoint = "qihoo360/360VL-8B"
#       6
# ...

# %% [markdown]
# ## Document Question Answering

# %%
from transformers import pipeline

nlp = pipeline(
    "document-question-answering",
    model="impira/layoutlm-document-qa",
)

nlp(
    "jetblue.png",
    "Extract all banner infrmation"
)
# {'score': 0.9943977, 'answer': 'us-001', 'start': 15, 'end': 15}

# nlp(
#     "https://miro.medium.com/max/787/1*iECQRIiOGTmEFLdWkVIH2g.jpeg",
#     "What is the purchase amount?"
# )
# # {'score': 0.9912159, 'answer': '$1,000,000,000', 'start': 97, 'end': 97}

# nlp(
#     "https://www.accountingcoach.com/wp-content/uploads/2013/10/income-statement-example@2x.png",
#     "What are the 2020 net sales?"
# )
# # {'score': 0.59147286, 'answer': '$ 3,750', 'start': 19, 'end': 20}
# Out:
# /usr/local/lib/python3.10/dist-packages/huggingface_hub/utils/_token.py:89: UserWarning:
# The secret `HF_TOKEN` does not exist in your Colab secrets.
# To authenticate with the Hugging Face Hub, create a token in your settings tab (https://huggingface.co/settings/tokens), set it as secret in your Google Colab and restart your session.
# You will be able to reuse this secret in all of your notebooks.
# Please note that authentication is recommended but still optional to access public models or datasets.
#   warnings.warn(
# config.json:   0%|          | 0.00/789 [00:00<?, ?B/s]
# model.safetensors:   0%|          | 0.00/511M [00:00<?, ?B/s]
# tokenizer_config.json:   0%|          | 0.00/315 [00:00<?, ?B/s]
# vocab.json:   0%|          | 0.00/798k [00:00<?, ?B/s]
# merges.txt:   0%|          | 0.00/456k [00:00<?, ?B/s]
# tokenizer.json:   0%|          | 0.00/1.36M [00:00<?, ?B/s]
# special_tokens_map.json:   0%|          | 0.00/239 [00:00<?, ?B/s]
# ...

# %%
import re

from transformers import DonutProcessor, VisionEncoderDecoderModel
# from datasets import load_dataset
import torch
from PIL import Image

processor = DonutProcessor.from_pretrained("naver-clova-ix/donut-base-finetuned-docvqa")
model = VisionEncoderDecoderModel.from_pretrained("naver-clova-ix/donut-base-finetuned-docvqa")

device = "cuda" if torch.cuda.is_available() else "cpu"
model.to(device)
# load document image from the DocVQA dataset
# dataset = load_dataset("hf-internal-testing/example-documents", split="test")
# image = dataset[0]["image"]

image = Image.open('jetblue1.png').convert('RGB')


# prepare decoder inputs
task_prompt = "<s_docvqa><s_question>{user_input}</s_question><s_answer>"
question = 'Extract all the barclays card offer from the image'
prompt = task_prompt.replace("{user_input}", question)
decoder_input_ids = processor.tokenizer(prompt, add_special_tokens=False, return_tensors="pt").input_ids

pixel_values = processor(image, return_tensors="pt").pixel_values

outputs = model.generate(
    pixel_values.to(device),
    decoder_input_ids=decoder_input_ids.to(device),
    max_length=model.decoder.config.max_position_embeddings,
    pad_token_id=processor.tokenizer.pad_token_id,
    eos_token_id=processor.tokenizer.eos_token_id,
    use_cache=True,
    bad_words_ids=[[processor.tokenizer.unk_token_id]],
    return_dict_in_generate=True,
)

sequence = processor.batch_decode(outputs.sequences)[0]
sequence = sequence.replace(processor.tokenizer.eos_token, "").replace(processor.tokenizer.pad_token, "")
sequence = re.sub(r"<.*?>", "", sequence, count=1).strip()  # remove first task start token
print(processor.token2json(sequence))
# Out:
# {'question': 'Extract all the barclays card offer from the image', 'answer': 'solo bags'}

# %%
from transformers import ViltProcessor, ViltForQuestionAnswering
import requests
from PIL import Image

# url = "http://images.cocodataset.org/val2017/000000039769.jpg"
image = Image.open('jetblue.png').convert('RGB')
text = 'Extract all the barclays card offer from the image'

processor = ViltProcessor.from_pretrained("dandelin/vilt-b32-finetuned-vqa")
model = ViltForQuestionAnswering.from_pretrained("dandelin/vilt-b32-finetuned-vqa")

# prepare inputs
encoding = processor(image, text, return_tensors="pt")

# forward pass
outputs = model(**encoding)
logits = outputs.logits
idx = logits.argmax(-1).item()
print("Predicted answer:", model.config.id2label[idx])
# Out:
# Predicted answer: unknown

# %%
1
